# %% [markdown]
# # Iris - Atividade modular

# %% [markdown]
# # Importar as bibliotecas

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the csv file

# %%
df = pd.read_csv('E:\\Eduardo\\Pós Graduação - XP - Engenharia de Dados\\Módulo 1 - Engenheiro de Dados\\Atividade Modular\\iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Exibe o formato da tabela

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# # Exibe as informações da tabela

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# # Descreve (análise descritiva) os dados

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Verifica se há valores nulos

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Quantidade de espécies individuais

# %%
data = df.drop_duplicates(subset='Species', )
# data.drop('Species', axis=1, inplace=True)
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 50    51            7.0           3.2            4.7           1.4
# 100  101            6.3           3.3            6.0           2.5
#
#              Species
# 0        Iris-setosa
# 50   Iris-versicolor
# 100   Iris-virginica

# %% [markdown]
# # Conta o número de Flores por Espécie

# %%
df.value_counts('Species')
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Plota as Espécies por Quantidade

# %%
sns.countplot(x='Species', data=df, )
plt.show()

# %% [markdown]
# # Plota as Espécies por Comprimento e Largura da Sépala

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=df, )

# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1,1), loc=2)
plt.show()

# %% [markdown]
# # Plota as Espécies por Comprimento e Largura da Pétala

# %%
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue='Species', data=df, )

# Placing legend outside the Figure
plt.legend(bbox_to_anchor=(1,1), loc=2)
plt.show()

# %% [markdown]
# # Mostra a Análise Estatística dos Dados (sépala e pétala)

# %%
sns.pairplot(df.drop(['Id'], axis=1), 
             hue='Species', height=2)

# %% [markdown]
# # Distribuição normal da Sépala e Pétala (Histograma)

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,10))

axes[0,0].set_title("Sepal Length")
axes[0,0].hist(df['SepalLengthCm'], bins=7)

axes[0,1].set_title('Sepal Width')
axes[0,1].hist(df['SepalWidthCm'], bins=5);

axes[1,0].set_title('Petal Length')
axes[1,0].hist(df['PetalLengthCm'], bins=6);

axes[1,1].set_title('Petal Width')
axes[1,1].hist(df['PetalWidthCm'], bins=6);

# %% [markdown]
# # Distribuição normal da Sépala e Pétala (Histograma com Distplot)

# %%
plot = sns.FacetGrid(df, hue='Species')
plot.map(sns.distplot, 'SepalLengthCm').add_legend()

plot = sns.FacetGrid(df, hue='Species')
plot.map(sns.displot, 'SepalWidthCm').add_legend()

plot = sns.FacetGrid(df, hue='Species')
plot.map(sns.distplot, 'PetalLengthCm').add_legend()

plot = sns.FacetGrid(df, hue='Species')
plot.map(sns.distplot, 'PetalWidthCm').add_legend()

plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # Mostra a correlação de pares de colunas

# %%
data.corr(method='pearson')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 data.corr(method='pearson')
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %% [markdown]
# # Mostra o Mapa de Calor

# %%
sns.heatmap(df.corr(method='pearson').drop(
            ['Id'], axis=1).drop(['Id'], axis=0), 
            annot=True );
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sns.heatmap(df.corr(method='pearson').drop(
#       2             ['Id'], axis=1).drop(['Id'], axis=0),
#       3             annot=True );
#       4 plt.show()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %% [markdown]
# # Plotar os box-plot para identificarmos os outliers

# %%
def graph(y):
    sns.boxplot(x='Species', y=y, data=df)

plt.figure(figsize=(10,10))

# Adding the subplot at the specified grid position
plt.subplot(221)
graph('SepalLengthCm')

plt.subplot(222)
graph('SepalWidthCm')

plt.subplot(223)
graph('PetalLengthCm')

plt.subplot(224)
graph('PetalWidthCm')

plt.show()
